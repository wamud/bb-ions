# %%
import stim
import numpy as np
from stimbposd import BPOSD

num_shots = 100

circuit = stim.Circuit.from_file("../circuits/n=288,k=12,d=18,p=0.005,b=X,noise=longchain,r=18,code=BB,A=300207,B=031020.stim") 

sampler = circuit.compile_detector_sampler()
shots, observables = sampler.sample(num_shots, separate_observables=True)

decoder = BPOSD(circuit.detector_error_model(), max_bp_iters=20)

predicted_observables = decoder.decode_batch(shots)
num_mistakes = np.sum(np.any(predicted_observables != observables, axis=1))

print(f"{num_mistakes}/{num_shots}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 7
#       3 from stimbposd import BPOSD
#       5 num_shots = 100
# ----> 7 circuit = stim.Circuit.from_file("../circuits/n=288,k=12,d=18,p=0.005,b=X,noise=longchain,r=18,code=BB,A=300207,B=031020.stim")
#       9 sampler = circuit.compile_detector_sampler()
#      10 shots, observables = sampler.sample(num_shots, separate_observables=True)
#
# ValueError: Failed to open '../circuits/n=288,k=12,d=18,p=0.005,b=X,noise=longchain,r=18,code=BB,A=300207,B=031020.stim' for reading.
